# %%
import pandas as pd
df = pd.read_csv('air.csv')
df
# Out:
#      ก๊าซซัลฟอร์ไดออกไซต์    ก๊าซไนโตรเจนออกไซต์  \
# 0                       3.2                 28.3
# 1                       5.2                 37.2
# 2                       3.0                 23.0
# 3                       4.3                 21.5
# 4                       3.3                 12.6
# 5                       2.8                  7.7
# 6                       2.3                 10.3
# 7                       1.5                 10.3
# 8                       1.3                 12.7
# 9                       2.8                 15.9
# 10                      3.2                 21.8
# 11                      3.0                 21.1
# 12                      2.6                 24.3
# 13                      1.7                 23.0
# 14                      2.4                 24.4
# 15                      2.0                 17.8
# 16                      0.9                 12.1
# 17                      1.2                 11.8
# 18                      2.4                 12.2
# 19                      3.0                 11.4
# 20                      1.9                 15.2
# 21                      1.5                 16.2
# 22                      1.9                 21.1
# 23                      2.7                 29.5
# 24                      3.0                 30.0
# 25                      3.0                 29.0
# 26                      2.0                 23.0
# 27                      3.0                 20.0
# 28                      2.0                 16.0
# 29                      1.0                 12.0
# ..                      ...                  ...
# 114                     NaN                  NaN
# 115                     2.0                  7.0
# 116                     2.0                  9.0
# 117                     2.0                 12.0
# 118                     3.0                 10.0
# 119                     3.0                 11.0
# 120                     1.0                  7.0
# 121                     1.0                 14.0
# 122                     0.0                 15.0
# 123                     1.0                 10.0
# 124                     1.0                  6.0
# 125                     1.0                  8.0
# 126                     1.0                  7.0
# 127                     NaN                  NaN
# 128                     NaN                  NaN
# 129                     2.0                  9.0
# 130                     3.0                 11.0
# 131                     3.0                 15.0
# 132                     3.0                 14.0
# 133                     4.0                 18.0
# 134                     3.0                 13.0
# 135                     3.0                 11.0
# 136                     3.0                  6.0
# 137                     1.0                  4.0
# 138                     0.0                  3.0
# 139                     0.0                  3.0
# 140                     0.0                  3.0
# 141                     NaN                  NaN
# 142                     NaN                  NaN
# 143                     NaN                  NaN
#
#      ก๊าซคาร์บอนมอนอกไซต์ 8 ชั่วโมง  ก๊าซโอโซน 1 ชั่วโมง
# 0                              1.30                 13.4
# 1                              1.40                 22.4
# 2                              1.10                 25.4
# 3                              0.80                 21.6
# 4                              1.00                  4.6
# 5                              0.70                 11.7
# 6                              0.60                 12.2
# 7                              0.70                  9.2
# 8                              0.70                 10.7
# 9                              0.90                 16.9
# 10                             0.90                 18.6
# 11                             1.00                 14.3
# 12                             1.40                 16.8
# 13                             0.90                 22.3
# 14                             0.80                 23.5
# 15                             0.60                 18.9
# 16                             0.50                 16.3
# 17                             0.40                 13.0
# 18                             0.40                 10.7
# 19                             0.40                 13.0
# 20                             0.70                  8.6
# 21                             0.60                 10.4
# 22                             0.80                 14.1
# 23                             1.10                 17.3
# 24                             1.00                 20.0
# 25                             1.10                 18.0
# 26                             0.80                 24.0
# 27                             1.00                 24.0
# 28                             0.60                 23.0
# 29                             0.40                 19.0
# ..                              ...                  ...
# 114                             NaN                  NaN
# 115                            0.21                  NaN
# 116                            0.44                  NaN
# 117                            0.80                  NaN
# 118                            0.61                  NaN
# 119                            0.67                  NaN
# 120                             NaN                  NaN
# 121                             NaN                  NaN
# 122                             NaN                  NaN
# 123                             NaN                  NaN
# 124                             NaN                  NaN
# 125                             NaN                  NaN
# 126                             NaN                  NaN
# 127                             NaN                  NaN
# 128                             NaN                  NaN
# 129                             NaN                  NaN
# 130                             NaN                  NaN
# 131                             NaN                  NaN
# 132                             NaN                  NaN
# 133                             NaN                  NaN
# 134                             NaN                  NaN
# 135                             NaN                  NaN
# 136                             NaN                  NaN
# 137                             NaN                  NaN
# 138                             NaN                  NaN
# 139                             NaN                  NaN
# 140                             NaN                  NaN
# 141                             NaN                  NaN
# 142                             NaN                  NaN
# 143                             NaN                  NaN
#
# [144 rows x 4 columns]

# %%
import numpy as np

print('Number of instances = %d' % (df.shape[0]))
print('Number of attributes = %d' % (df.shape[1]))

print('\nNumber of missing values:')
for col in df.columns:
    print('\t%s: %d' % (col,df[col].isna().sum()))
# Out:
# Number of instances = 144
# Number of attributes = 4
#
# Number of missing values:
# 	ก๊าซซัลฟอร์ไดออกไซต์  : 7
# 	ก๊าซไนโตรเจนออกไซต์: 9
# 	ก๊าซคาร์บอนมอนอกไซต์ 8 ชั่วโมง: 26
# 	ก๊าซโอโซน 1 ชั่วโมง: 36

# %%
df.dropna(inplace=True)

# %%
import numpy as np

print('Number of instances = %d' % (df.shape[0]))
print('Number of attributes = %d' % (df.shape[1]))

print('\nNumber of missing values:')
for col in df.columns:
    print('\t%s: %d' % (col,df[col].isna().sum()))
# Out:
# Number of instances = 106
# Number of attributes = 4
#
# Number of missing values:
# 	ก๊าซซัลฟอร์ไดออกไซต์  : 0
# 	ก๊าซไนโตรเจนออกไซต์: 0
# 	ก๊าซคาร์บอนมอนอกไซต์ 8 ชั่วโมง: 0
# 	ก๊าซโอโซน 1 ชั่วโมง: 0

# %%
df
# Out:
#      ก๊าซซัลฟอร์ไดออกไซต์    ก๊าซไนโตรเจนออกไซต์  \
# 0                       3.2                 28.3
# 1                       5.2                 37.2
# 2                       3.0                 23.0
# 3                       4.3                 21.5
# 4                       3.3                 12.6
# 5                       2.8                  7.7
# 6                       2.3                 10.3
# 7                       1.5                 10.3
# 8                       1.3                 12.7
# 9                       2.8                 15.9
# 10                      3.2                 21.8
# 11                      3.0                 21.1
# 12                      2.6                 24.3
# 13                      1.7                 23.0
# 14                      2.4                 24.4
# 15                      2.0                 17.8
# 16                      0.9                 12.1
# 17                      1.2                 11.8
# 18                      2.4                 12.2
# 19                      3.0                 11.4
# 20                      1.9                 15.2
# 21                      1.5                 16.2
# 22                      1.9                 21.1
# 23                      2.7                 29.5
# 24                      3.0                 30.0
# 25                      3.0                 29.0
# 26                      2.0                 23.0
# 27                      3.0                 20.0
# 28                      2.0                 16.0
# 29                      1.0                 12.0
# ..                      ...                  ...
# 76                      1.0                 19.0
# 77                      1.0                 15.0
# 78                      1.0                 12.0
# 81                      0.0                 10.0
# 82                      0.0                  4.0
# 83                      1.0                 10.0
# 84                      1.0                 17.0
# 85                      1.0                 12.0
# 86                      2.0                 11.0
# 87                      1.0                  9.0
# 88                      1.0                  6.0
# 89                      1.0                  6.0
# 90                      1.0                  7.0
# 91                      1.0                  4.0
# 92                      1.0                  6.0
# 93                      1.0                  7.0
# 94                      1.0                  9.0
# 95                      2.0                  5.0
# 96                      2.0                 17.0
# 97                      1.0                 14.0
# 98                      1.0                  6.0
# 99                      1.0                  6.0
# 100                     1.0                  6.0
# 101                     1.0                  6.0
# 102                     1.0                  5.0
# 103                     1.0                  6.0
# 104                     0.0                  8.0
# 105                     1.0                 10.0
# 106                     1.0                 10.0
# 107                     1.0                  8.0
#
#      ก๊าซคาร์บอนมอนอกไซต์ 8 ชั่วโมง  ก๊าซโอโซน 1 ชั่วโมง
# 0                              1.30                 13.4
# 1                              1.40                 22.4
# 2                              1.10                 25.4
# 3                              0.80                 21.6
# 4                              1.00                  4.6
# 5                              0.70                 11.7
# 6                              0.60                 12.2
# 7                              0.70                  9.2
# 8                              0.70                 10.7
# 9                              0.90                 16.9
# 10                             0.90                 18.6
# 11                             1.00                 14.3
# 12                             1.40                 16.8
# 13                             0.90                 22.3
# 14                             0.80                 23.5
# 15                             0.60                 18.9
# 16                             0.50                 16.3
# 17                             0.40                 13.0
# 18                             0.40                 10.7
# 19                             0.40                 13.0
# 20                             0.70                  8.6
# 21                             0.60                 10.4
# 22                             0.80                 14.1
# 23                             1.10                 17.3
# 24                             1.00                 20.0
# 25                             1.10                 18.0
# 26                             0.80                 24.0
# 27                             1.00                 24.0
# 28                             0.60                 23.0
# 29                             0.40                 19.0
# ..                              ...                  ...
# 76                             0.89                 25.0
# 77                             0.64                 18.0
# 78                             0.47                 12.0
# 81                             0.35                 26.0
# 82                             0.19                 23.0
# 83                             0.22                 31.0
# 84                             0.26                 31.0
# 85                             0.28                 37.0
# 86                             0.57                 44.0
# 87                             0.34                 43.0
# 88                             0.14                 33.0
# 89                             0.38                 26.0
# 90                             0.21                 18.0
# 91                             0.25                 17.0
# 92                             0.31                 16.0
# 93                             0.33                 16.0
# 94                             0.54                 22.0
# 95                             0.70                 31.0
# 96                             0.86                 32.0
# 97                             0.80                 32.0
# 98                             0.76                 42.0
# 99                             0.64                 45.0
# 100                            0.46                 35.0
# 101                            0.45                 33.0
# 102                            0.44                 24.0
# 103                            0.45                 21.0
# 104                            0.50                 19.0
# 105                            0.61                 21.0
# 106                            0.60                 20.0
# 107                            0.77                 26.0
#
# [106 rows x 4 columns]

# %%
import pandas as pd
from sklearn import preprocessing

# Set charts to view inline
# %matplotlib inline

# %%
min_max_scaler = preprocessing.MinMaxScaler()

# Create an object to transform the data to fit minmax processor
x_scaled = min_max_scaler.fit_transform(df)

# Run the normalizer on the dataframe
df_normalized = pd.DataFrame(x_scaled)

# %%
df_normalized
# Out:
#             0         1         2         3
# 0    0.533333  0.731928  0.044857  0.217822
# 1    0.866667  1.000000  0.048724  0.440594
# 2    0.500000  0.572289  0.037123  0.514851
# 3    0.716667  0.527108  0.025522  0.420792
# 4    0.550000  0.259036  0.033256  0.000000
# 5    0.466667  0.111446  0.021655  0.175743
# 6    0.383333  0.189759  0.017788  0.188119
# 7    0.250000  0.189759  0.021655  0.113861
# 8    0.216667  0.262048  0.021655  0.150990
# 9    0.466667  0.358434  0.029389  0.304455
# 10   0.533333  0.536145  0.029389  0.346535
# 11   0.500000  0.515060  0.033256  0.240099
# 12   0.433333  0.611446  0.048724  0.301980
# 13   0.283333  0.572289  0.029389  0.438119
# 14   0.400000  0.614458  0.025522  0.467822
# 15   0.333333  0.415663  0.017788  0.353960
# 16   0.150000  0.243976  0.013921  0.289604
# 17   0.200000  0.234940  0.010054  0.207921
# 18   0.400000  0.246988  0.010054  0.150990
# 19   0.500000  0.222892  0.010054  0.207921
# 20   0.316667  0.337349  0.021655  0.099010
# 21   0.250000  0.367470  0.017788  0.143564
# 22   0.316667  0.515060  0.025522  0.235149
# 23   0.450000  0.768072  0.037123  0.314356
# 24   0.500000  0.783133  0.033256  0.381188
# 25   0.500000  0.753012  0.037123  0.331683
# 26   0.333333  0.572289  0.025522  0.480198
# 27   0.500000  0.481928  0.033256  0.480198
# 28   0.333333  0.361446  0.017788  0.455446
# 29   0.166667  0.240964  0.010054  0.356436
# ..        ...       ...       ...       ...
# 76   0.166667  0.451807  0.029002  0.504950
# 77   0.166667  0.331325  0.019335  0.331683
# 78   0.166667  0.240964  0.012761  0.183168
# 79   0.000000  0.180723  0.008121  0.529703
# 80   0.000000  0.000000  0.001933  0.455446
# 81   0.166667  0.180723  0.003094  0.653465
# 82   0.166667  0.391566  0.004640  0.653465
# 83   0.166667  0.240964  0.005414  0.801980
# 84   0.333333  0.210843  0.016628  0.975248
# 85   0.166667  0.150602  0.007734  0.950495
# 86   0.166667  0.060241  0.000000  0.702970
# 87   0.166667  0.060241  0.009281  0.529703
# 88   0.166667  0.090361  0.002707  0.331683
# 89   0.166667  0.000000  0.004254  0.306931
# 90   0.166667  0.060241  0.006574  0.282178
# 91   0.166667  0.090361  0.007347  0.282178
# 92   0.166667  0.150602  0.015468  0.430693
# 93   0.333333  0.030120  0.021655  0.653465
# 94   0.333333  0.391566  0.027842  0.678218
# 95   0.166667  0.301205  0.025522  0.678218
# 96   0.166667  0.060241  0.023975  0.925743
# 97   0.166667  0.060241  0.019335  1.000000
# 98   0.166667  0.060241  0.012374  0.752475
# 99   0.166667  0.060241  0.011988  0.702970
# 100  0.166667  0.030120  0.011601  0.480198
# 101  0.166667  0.060241  0.011988  0.405941
# 102  0.000000  0.120482  0.013921  0.356436
# 103  0.166667  0.180723  0.018175  0.405941
# 104  0.166667  0.180723  0.017788  0.381188
# 105  0.166667  0.120482  0.024362  0.529703
#
# [106 rows x 4 columns]

# %%
df_normalized.plot(kind='line')

# %%
df_test = df_normalized

# %%
df_test
testsize = 32
trainsize = df_test[:~testsize].shape[0]
trainsize
# Out:
# 73

# %%
X_train = df_test[[0]][:~testsize]
X_test = df_test[[1]][trainsize:]
Y_train = df_test[2][:~testsize]
Y_test = df_test[3][trainsize:]

# %%
import matplotlib.pyplot as plt
plt.subplot(2, 2, 1)
plt.scatter(X_train, Y_train)
plt.title('Training Set')
plt.subplot(2, 2, 2)
plt.scatter(X_test, Y_test)
plt.title('Testing Set')
# Out:
# Text(0.5,1,'Testing Set')

# %%
from sklearn.linear_model import LinearRegression

model = LinearRegression()
model.fit(X_train, Y_train)

Y_pred = model.predict(X_test)

plt.scatter(X_test, Y_test)
plt.plot(X_test, Y_pred, color='red', linewidth = 3)
plt.show()

# %%
from sklearn import metrics

print('mean_absolute_error = ',metrics.mean_absolute_error(Y_test, Y_pred))
print('mean_squared_error = ',metrics.mean_squared_error(Y_test, Y_pred))
print('mean_squared_error = ',np.sqrt(metrics.mean_squared_error(Y_test, Y_pred)))
# Out:
# mean_absolute_error =  0.3824083488179291
# mean_squared_error =  0.19296742546708792
# mean_squared_error =  0.4392805771566595

# %%
df_normalized[0].plot(kind='line')

# %%
df_normalized[1].plot(kind='line')

# %%
df_normalized[2].plot(kind='line')

# %%
df_normalized[3].plot(kind='line')
